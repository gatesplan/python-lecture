# %% [markdown]
# # Factory 패턴과 스태틱 메서드
#
# 팩토리 패턴은 객체를 생성하는 행동을 별도의 클래스로 군집화하여 편의성, 재사용성을 극대화하는 방식이다.
#
# 스태틱 메서드는 상태를 가지지 않는 (stateless) 클래스 혹은 상태가 필요 없는 메서드로,
#
# 클래스에서 객체를 생성하지 않고도 바로 쓸 수 있다.

# %%
from mypy.stubutil import CantImport

# 생산품 - 오리, 고양이, 개
class Duck:
    def quack(self):
        return "꽥꽥"

    def swim(self):
        return "오리가 헤엄칩니다."

    def fly(self):
        return "오리가 날아갑니다."

class Cat:
    def meow(self):
        return "야옹야옹"

    def scratch(self):
        return "고양이가 할퀴었습니다."

class Dog:
    def bark(self):
        return "멍멍"

    def fetch(self):
        return "개가 공을 가져옵니다."

class Fish:
    def fishfish(self):
        return "do nothing"


class AnimalFactory:
    @staticmethod
    def create(type: str, n: int = 1):
        if type == "duck":
            return AnimalFactory.create_duck(n)
        elif type == "cat":
            return AnimalFactory.create_cat(n)
        elif type == "dog":
            return AnimalFactory.create_dog(n)
        elif type == "fish":
            return AnimalFactory.create_fish(n)
        else:
            raise ValueError(f"Unknown animal type: {type}")

    @staticmethod
    def create_duck(n: int = 1): # 함수x 메서드0
        return [Duck() for _ in range(n)]

    @staticmethod
    def create_cat(n: int = 1):
        return [Cat() for _ in range(n)]

    @staticmethod
    def create_dog(n: int = 1):
        return [Dog() for _ in range(n)]

    @staticmethod
    def create_fish(n: int = 100):
        return [Fish() for _ in range(n)]

AnimalFactory.create("fish", 100)
# Out:
# [<__main__.Fish at 0x2346bdd0980>,
#  <__main__.Fish at 0x2346bdcc550>,
#  <__main__.Fish at 0x2346bdcc7d0>,
#  <__main__.Fish at 0x2346bcb6c40>,
#  <__main__.Fish at 0x2346bcb7360>,
#  <__main__.Fish at 0x2346bdc1130>,
#  <__main__.Fish at 0x2346b027020>,
#  <__main__.Fish at 0x2346bc929c0>,
#  <__main__.Fish at 0x2346bcbed50>,
#  <__main__.Fish at 0x2346bcbeb50>,
#  <__main__.Fish at 0x2346bd694f0>,
#  <__main__.Fish at 0x2346bd695e0>,
#  <__main__.Fish at 0x2346bdd8e50>,
#  <__main__.Fish at 0x2346bdd90f0>,
#  <__main__.Fish at 0x2346bda8530>,
#  <__main__.Fish at 0x2346bc7e690>,
#  <__main__.Fish at 0x2346bc7e150>,
#  <__main__.Fish at 0x2346bca2200>,
#  <__main__.Fish at 0x2346bca1f40>,
#  <__main__.Fish at 0x2346bdcae90>,
#  <__main__.Fish at 0x2346bdc9c70>,
#  <__main__.Fish at 0x2346b702330>,
#  <__main__.Fish at 0x2346bdb0750>,
#  <__main__.Fish at 0x2346bdb0850>,
#  <__main__.Fish at 0x2346bd10e50>,
#  <__main__.Fish at 0x2346bd122e0>,
#  <__main__.Fish at 0x2346bd83230>,
#  <__main__.Fish at 0x2346bd83290>,
#  <__main__.Fish at 0x2346bdc66c0>,
#  <__main__.Fish at 0x2346bdc6850>,
#  <__main__.Fish at 0x2346bdc6440>,
#  <__main__.Fish at 0x2346bdc6260>,
#  <__main__.Fish at 0x2346bdc6df0>,
#  <__main__.Fish at 0x2346bdc6da0>,
#  <__main__.Fish at 0x2346bdc6e40>,
#  <__main__.Fish at 0x2346bdc6e90>,
#  <__main__.Fish at 0x2346bdc6ee0>,
#  <__main__.Fish at 0x2346bdc6f30>,
#  <__main__.Fish at 0x2346bdc6f80>,
#  <__main__.Fish at 0x2346bdc6fd0>,
#  <__main__.Fish at 0x2346bdc7020>,
#  <__main__.Fish at 0x2346bdc7110>,
#  <__main__.Fish at 0x2346bdc7160>,
#  <__main__.Fish at 0x2346bdc71b0>,
#  <__main__.Fish at 0x2346bdc7200>,
#  <__main__.Fish at 0x2346bdc7250>,
#  <__main__.Fish at 0x2346bdc72a0>,
#  <__main__.Fish at 0x2346bdc72f0>,
#  <__main__.Fish at 0x2346bdc7340>,
#  <__main__.Fish at 0x2346bdc7390>,
#  <__main__.Fish at 0x2346bdc73e0>,
#  <__main__.Fish at 0x2346bdc7430>,
#  <__main__.Fish at 0x2346bdc7480>,
#  <__main__.Fish at 0x2346bdc74d0>,
#  <__main__.Fish at 0x2346bdc7520>,
#  <__main__.Fish at 0x2346bdc7570>,
#  <__main__.Fish at 0x2346bdc75c0>,
#  <__main__.Fish at 0x2346bdc7610>,
#  <__main__.Fish at 0x2346bdc7660>,
#  <__main__.Fish at 0x2346bdc76b0>,
#  <__main__.Fish at 0x2346bdb9090>,
#  <__main__.Fish at 0x2346bdb8e60>,
#  <__main__.Fish at 0x2346bdb8f00>,
#  <__main__.Fish at 0x2346bdb9130>,
#  <__main__.Fish at 0x2346bdb9540>,
#  <__main__.Fish at 0x2346bdb9590>,
#  <__main__.Fish at 0x2346bdb8f50>,
#  <__main__.Fish at 0x2346bdb9040>,
#  <__main__.Fish at 0x2346bdb9450>,
#  <__main__.Fish at 0x2346bdb9220>,
#  <__main__.Fish at 0x2346bdb91d0>,
#  <__main__.Fish at 0x2346bdb8e10>,
#  <__main__.Fish at 0x2346bdb95e0>,
#  <__main__.Fish at 0x2346bdb8ff0>,
#  <__main__.Fish at 0x2346bdb98b0>,
#  <__main__.Fish at 0x2346bdb9900>,
#  <__main__.Fish at 0x2346bdb9950>,
#  <__main__.Fish at 0x2346bdb99a0>,
#  <__main__.Fish at 0x2346bdb99f0>,
#  <__main__.Fish at 0x2346bdb9a40>,
#  <__main__.Fish at 0x2346bdb9a90>,
#  <__main__.Fish at 0x2346bdb9ae0>,
#  <__main__.Fish at 0x2346bdb9b30>,
#  <__main__.Fish at 0x2346bdb9b80>,
#  <__main__.Fish at 0x2346bdb9bd0>,
#  <__main__.Fish at 0x2346bdb9c20>,
#  <__main__.Fish at 0x2346bdb9c70>,
#  <__main__.Fish at 0x2346bdb9cc0>,
#  <__main__.Fish at 0x2346bdb9d10>,
#  <__main__.Fish at 0x2346bdb9d60>,
#  <__main__.Fish at 0x2346bdb9db0>,
#  <__main__.Fish at 0x2346bdb9e00>,
#  <__main__.Fish at 0x2346bdb9e50>,
#  <__main__.Fish at 0x2346bdb9ea0>,
#  <__main__.Fish at 0x2346bdb9ef0>,
#  <__main__.Fish at 0x2346bdb9f40>,
#  <__main__.Fish at 0x2346bdb9f90>,
#  <__main__.Fish at 0x2346bdb9fe0>,
#  <__main__.Fish at 0x2346bdba030>,
#  <__main__.Fish at 0x2346bdba080>]

# %%
class ClassifierFactory:
    @staticmethod
    def create_knn(n_neighbors: int = 5):
        from sklearn.neighbors import KNeighborsClassifier
        return KNeighborsClassifier(n_neighbors=n_neighbors)

    @staticmethod
    def create_svm(kernel: str = 'linear'):
        from sklearn.svm import SVC
        return SVC(kernel=kernel)
